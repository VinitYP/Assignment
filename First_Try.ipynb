# %%
import requests
from bs4 import BeautifulSoup
import csv


def scrape_amazon_products(url):
    response = requests.get(url)
    if response.status_code == 200:

        soup = BeautifulSoup(response.content, 'html.parser')


        product_containers = soup.find_all('div', {'data-component-type': 's-search-result'})


        for container in product_containers:

            product_name = container.find('span', {'class': 'a-size-medium'}).text.strip()
            product_url = container.find('a', {'class': 'a-link-normal'})['href']
            product_price = container.find('span', {'class': 'a-price-whole'}).text.strip()
            rating = container.find('span', {'class': 'a-icon-alt'}).text.strip()
            num_reviews = container.find('span', {'class': 'a-size-base'}).text.strip()
            asin = container['data-asin']



            print('Product Name:', product_name)
            print('Product URL:', product_url)
            print('Product Price:', product_price)
            print('Rating:', rating)
            print('Number of Reviews:', num_reviews)
            print('ASIN: ',asin)
            print('-------------------------------------')


            with open('products.csv', 'a', newline='', encoding='utf-8') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow([product_name, product_url, product_price, rating, num_reviews])
    else:
        print('Failed to retrieve the webpage')


for page in range(1, 21):
    url = f'https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_{page}'
    scrape_amazon_products(url)
# Out:
# Failed to retrieve the webpage
# Failed to retrieve the webpage
# Failed to retrieve the webpage
# Failed to retrieve the webpage
# Failed to retrieve the webpage
# Failed to retrieve the webpage
# Product Name: Skybags Brat Black 46 Cms Casual Backpack
# Product URL: /gp/bestsellers/luggage/2917436031/ref=sr_bs_0_2917436031_1
# Product Price: 599
# Rating: 4.1 out of 5 stars
# Number of Reviews: 5,001
# ASIN:  B08Z1HHHTD
# -------------------------------------
# Product Name: American Tourister 32 Ltrs Black Casual Backpack (AMT FIZZ SCH BAG 02 - BLACK)
# Product URL: /American-Tourister-AMT-SCH-02/dp/B07CJCGM1M
# Product Price: 1,199
# Rating: 4.0 out of 5 stars
# Number of Reviews: 55,177
# ASIN:  B07CJCGM1M
# -------------------------------------
# Product Name: Wesley Milestone 2.0 Casual Waterproof Laptop Backpack/Office Bag/School Bag/College Bag/Business Bag/Travel Backpack (Dimensions:13x18 inches) (Compatible with 39.62cm(15.6inch laptop) 30 L (Blue & black)
# Product URL: /Wesley-Milestone-Waterproof-Backpack-Business/dp/B084JGJ8PF/ref=ice_ac_b_dpb
# Product Price: 550
# Rating: 4.3 out of 5 stars
# Number of Reviews: 11,551
# ASIN:  B084JGJ8PF
# -------------------------------------
# Product Name: American Tourister VALEX BLACK LAPTOP BACKPACK 28 Ltrs,Volume, LAPTOP COMPARTMENT, BOTTLE POCKET, FRONT ORGANIZER
# Product URL: /gp/bestsellers/computers/1375464031/ref=sr_bs_3_1375464031_1
# Product Price: 1,299
# Rating: 4.3 out of 5 stars
# Number of Reviews: 417
# ASIN:  B0BTD4S4XF
# -------------------------------------
# Product Name: Half Moon 35L Water Resistant 15.6 inch Laptop Bag for Men/Backpack for Men, Navy Blue | Office Bag for Men/Office Bag for Women with Padded Laptop Compartment | Rain Cover & Reflective Strips
# Product URL: /Half-Moon-Waterproof-Backpack-Students/dp/B085MHDJ93
# Product Price: 649
# Rating: 3.9 out of 5 stars
# Number of Reviews: 16,375
# ASIN:  B085MHDJ93
# -------------------------------------
# Product Name: Gear Aspire 30L Water Restant Office Laptop Bag/Backpack for Men/Women/(Black)
